# %%
import random
import re
from pyecharts import options as opts
from pyecharts.charts import HeatMap
from pyecharts.charts import Pie
from pyecharts.faker import Faker

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

list2 = [
    {"value": 9.2384e-5, "percent": 9.2384e-5 / (9.2384e-5)},
    {"value": 0.0166566, "percent": 0.0166566 / (0.0166566)},
]

list3 = [
    {"value": 0.0211428, "percent": 0.0211428 / (9.2384e-5)},
    {"value": 0.0383883, "percent": 0.0383883 / (0.0166566)},
]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["平均读取Hit/Miss用时", "平均写入Hit/Miss用时",])
    .add_yaxis("Miss", list2, stack="stack1", category_gap="50%")
    .add_yaxis("Hit", list3, stack="stack1", category_gap="50%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode(
                "function(x){return '加速比:'+Number(x.data.percent * 100).toFixed() + '%';}"
            ),
        )
    )
#     .render_notebook()
    .render("bar-加速比.html")
)
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6584eba78cbb4d5aa0b8eda33f8bdb17" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6584eba78cbb4d5aa0b8eda33f8bdb17 = echarts.init(
#                     document.getElementById('6584eba78cbb4d5aa0b8eda33f8bdb17'), 'light', {renderer: 'canvas'});
#                 var option_6584eba78cbb4d5aa0b8eda33f8bdb17 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "Miss",
#             "legendHoverLink": true,
#             "data": [
#                 {
#                     "value": 9.2384e-05,
#                     "percent": 1.0
#                 },
#                 {
#                     "value": 0.0166566,
#                     "percent": 1.0
#                 }
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "50%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return '\u52a0\u901f\u6bd4:'+Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Hit",
#             "legendHoverLink": true,
#             "data": [
#                 {
#                     "value": 0.0211428,
#                     "percent": 228.85781087634223
#                 },
#                 {
#                     "value": 0.0383883,
#                     "percent": 2.304690032779799
#                 }
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "50%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return '\u52a0\u901f\u6bd4:'+Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Miss",
#                 "Hit"
#             ],
#             "selected": {
#                 "Miss": true,
#                 "Hit": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e73\u5747\u8bfb\u53d6Hit/Miss\u7528\u65f6",
#                 "\u5e73\u5747\u5199\u5165Hit/Miss\u7528\u65f6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_6584eba78cbb4d5aa0b8eda33f8bdb17.setOption(option_6584eba78cbb4d5aa0b8eda33f8bdb17);
#         });
#     </script>

# %%
file = open("data-5w-50w-zipf.txt","r+")
# file = open("in.txt","r+")
content = file.read()
content = re.split('\n|,',content)
cnt = {i:0 for i in range(0,50001)}

for i in range(1,len(content),2):
    cnt[int(content[i])]+=1
    
val = []
row = 20
col = 10
block = 250
mini = 1e9
maxi = 0
for i in range(row):
    for j in range(col):
        fre = 0
        for k in range (block):
            fre += cnt[i*row*col+j*block+k]
        val.append((j,i,fre))
        mini = min(mini,fre)
        maxi = max(maxi,fre)

heat = (
    HeatMap()
    .add_xaxis([block*i for i in range(col)])
    .add_yaxis(
        "",
        [block*i*col for i in range(row)],
        val,
        label_opts=opts.LabelOpts(is_show=True,position="inside"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="page调用次数热力图",pos_left="center"),
        visualmap_opts=opts.VisualMapOpts(
            min_=mini, max_=maxi/25, is_calculable=True, orient="horizontal", pos_left="center"
        )
    )    
#     .render_notebook()
    .render("heatmap_with_label_show.html")
)
# Out:
# 'C:\\Users\\10573\\Desktop\\StudyNotes\\上课\\高级数据库\\实验\\heatmap_with_label_show.html'

# %%
# inner_x_data = [ "Read Hit次数", "Read Miss次数"]
# inner_y_data = [86595, 255210-86595]
# inner_data_pair = [list(z) for z in zip(inner_x_data, inner_y_data)]

# outer_x_data = [ "Runtime of Read Hit（ms）", "Runtime of Read Miss（ms）"]
# outer_y_data = [3573-3565, 3565]
# outer_data_pair = [list(z) for z in zip(outer_x_data, outer_y_data)]

inner_x_data = [ "Write Hit次数", "Write Miss次数"]
inner_y_data = [82970, 244790-82970]
inner_data_pair = [list(z) for z in zip(inner_x_data, inner_y_data)]

outer_x_data = [ "Runtime of Write Hit（ms）", "Runtime of Write Miss（ms）"]
outer_y_data = [7594-6212, 7594]
outer_data_pair = [list(z) for z in zip(outer_x_data, outer_y_data)]

(
    Pie(init_opts=opts.InitOpts(width="800px", height="400px"))
    .add(
        series_name="",
        data_pair=inner_data_pair,
        radius=[0, "30%"],
        label_opts=opts.LabelOpts(
            position="inner",
            formatter=" {b}:{c}  per:{d}%  ",
        ),
    )
    .add(
        series_name="",
        radius=["40%", "55%"],
        data_pair=outer_data_pair,
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },
                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },
                "b": {"fontSize": 16, "lineHeight": 33},
                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left="left", orient="vertical"))
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        )
    )
#     .render_notebook()
    .render("pie of Read time.html")
)
